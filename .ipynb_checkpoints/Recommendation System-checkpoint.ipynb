# %%
pip install spotipy
# Out:
# Collecting spotipy
#   Downloading spotipy-2.23.0-py3-none-any.whl (29 kB)
# Requirement already satisfied: urllib3>=1.26.0 in /Users/jovitagandhi/opt/anaconda3/lib/python3.9/site-packages (from spotipy) (1.26.9)
# Requirement already satisfied: requests>=2.25.0 in /Users/jovitagandhi/opt/anaconda3/lib/python3.9/site-packages (from spotipy) (2.27.1)
# Collecting redis>=3.5.3
#   Downloading redis-4.5.4-py3-none-any.whl (238 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.9/238.9 kB 7.0 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.15.0 in /Users/jovitagandhi/opt/anaconda3/lib/python3.9/site-packages (from spotipy) (1.16.0)
# Collecting async-timeout>=4.0.2
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/jovitagandhi/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.25.0->spotipy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jovitagandhi/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.25.0->spotipy) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jovitagandhi/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.25.0->spotipy) (2021.10.8)
# Installing collected packages: async-timeout, redis, spotipy
#   Attempting uninstall: async-timeout
#     Found existing installation: async-timeout 4.0.1
#     Uninstalling async-timeout-4.0.1:
#       Successfully uninstalled async-timeout-4.0.1
# Successfully installed async-timeout-4.0.2 redis-4.5.4 spotipy-2.23.0
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /Users/jovitagandhi/opt/anaconda3/lib/python3.9/site-packages (23.0.1)
# Collecting pip
#   Downloading pip-23.1.1-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 14.2 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 23.0.1
#     Uninstalling pip-23.0.1:
#       Successfully uninstalled pip-23.0.1
# Successfully installed pip-23.1.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
cid = "9077762b627041aaa144a2521e1664d7"
secret = "cbf7e75d1c7e4a85a3214b06aca48467"

# %%
#Authentication - without user
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF?si=1333723a6eff4b7f"
playlist_URI = playlist_link.split("/")[-1].split("?")[0]
track_uris = [x["track"]["uri"] for x in sp.playlist_tracks(playlist_URI)["items"]]

# %%
for track in sp.playlist_tracks(playlist_URI)["items"]:
    #URI
    track_uri = track["track"]["uri"]
    
    #Track name
    track_name = track["track"]["name"]
    print(track_name)
    
    #Main Artist
    artist_uri = track["track"]["artists"][0]["uri"]
    artist_info = sp.artist(artist_uri)
    
    
    #Name, popularity, genre
    artist_name = track["track"]["artists"][0]["name"]
    artist_pop = artist_info["popularity"]
    artist_genres = artist_info["genres"]
    print(artist_name,artist_pop,artist_genres)
    
    #Album
    album = track["track"]["album"]["name"]
    print(album)
    
    #Popularity of the track
    track_pop = track["track"]["popularity"]
    print(track_pop)
    print()
# Out:
# Ella Baila Sola
# Eslabon Armado 85 ['corrido', 'corridos tumbados', 'nueva musica mexicana', 'sad sierreno', 'sierreno']
# Ella Baila Sola
# 99
#
# Flowers
# Miley Cyrus 90 ['pop']
# Endless Summer Vacation
# 91
#
# La Bebe - Remix
# Yng Lvcas 80 []
# La Bebe (Remix)
# 97
#
# un x100to
# Grupo Frontera 86 ['musica chihuahuense', 'nueva musica mexicana']
# un x100to
# 93
#
# TQG
# KAROL G 92 ['reggaeton', 'reggaeton colombiano', 'trap latino', 'urbano latino']
# MAÑANA SERÁ BONITO
# 98
#
# Kill Bill
# SZA 92 ['pop', 'r&b', 'rap']
# SOS
# 95
#
# BESO
# ROSALÍA 87 ['pop', 'r&b en espanol']
# RR
# 96
#
# Cupid - Twin Ver.
# FIFTY FIFTY 79 ['k-pop girl group']
# The Beginning: Cupid
# 93
#
# Daylight
# David Kushner 76 ['gen z singer-songwriter']
# Daylight
# 90
#
# Boy's a liar Pt. 2
# PinkPantheress 83 []
# Boy's a liar Pt. 2
# 98
#
# As It Was
# Harry Styles 89 ['pop']
# Harry's House
# 93
#
# PRC
# Peso Pluma 93 ['corrido', 'nueva musica mexicana', 'sad sierreno', 'sierreno']
# PRC
# 95
#
# Die For You (with Ariana Grande) - Remix
# The Weeknd 97 ['canadian contemporary r&b', 'canadian pop', 'pop']
# Starboy (Deluxe)
# 87
#
# Classy 101
# Feid 93 ['colombian pop', 'pop reggaeton', 'reggaeton colombiano', 'trap latino', 'urbano latino']
# Classy 101
# 92
#
# Creepin' (with The Weeknd & 21 Savage)
# Metro Boomin 90 ['hip hop', 'rap', 'trap']
# HEROES & VILLAINS
# 97
#
# Calm Down (with Selena Gomez)
# Rema 82 ['nigerian pop']
# Calm Down (with Selena Gomez)
# 96
#
# Yandel 150
# Yandel 82 ['latin hip hop', 'reggaeton', 'trap latino', 'urbano latino']
# Resistencia
# 91
#
# Chemical
# Post Malone 89 ['dfw rap', 'melodic rap', 'pop', 'rap']
# Chemical
# 87
#
# AMG
# Natanael Cano 87 ['corrido', 'corridos tumbados', 'musica mexicana', 'nueva musica mexicana', 'sad sierreno', 'sierreno']
# AMG
# 95
#
# El Azul
# Junior H 89 ['corrido', 'corridos tumbados', 'musica mexicana', 'nueva musica mexicana', 'sad sierreno', 'sierreno']
# El Azul
# 94
#
# Anti-Hero
# Taylor Swift 100 ['pop']
# Midnights
# 95
#
# Last Night
# Morgan Wallen 92 ['contemporary country']
# One Thing At A Time
# 89
#
# Search & Rescue
# Drake 97 ['canadian hip hop', 'canadian pop', 'hip hop', 'rap', 'toronto rap']
# Search & Rescue
# 91
#
# Die For You
# The Weeknd 97 ['canadian contemporary r&b', 'canadian pop', 'pop']
# Starboy
# 92
#
# Shakira: Bzrp Music Sessions, Vol. 53
# Bizarrap 87 ['argentine hip hop', 'pop venezolano', 'trap argentino', 'trap latino', 'urbano latino']
# Shakira: Bzrp Music Sessions, Vol. 53
# 97
#
# FLOWER
# JISOO 77 ['k-pop']
# ME
# 87
#
# I'm Good (Blue)
# David Guetta 89 ['big room', 'dance pop', 'edm', 'pop', 'pop dance']
# I'm Good (Blue)
# 95
#
# Unholy (feat. Kim Petras)
# Sam Smith 87 ['pop', 'uk pop']
# Gloria
# 87
#
# Heat Waves
# Glass Animals 78 ['gauze pop', 'indietronica', 'modern rock', 'shiver pop']
# Dreamland
# 87
#
# Here With Me
# d4vd 81 ['bedroom pop']
# Here With Me
# 95
#
# I Wanna Be Yours
# Arctic Monkeys 87 ['garage rock', 'modern rock', 'permanent wave', 'rock', 'sheffield indie']
# AM
# 94
#
# golden hour
# JVKE 80 ['modern indie pop']
# this is what ____ feels like (Vol. 1-4)
# 91
#
# Starboy
# The Weeknd 97 ['canadian contemporary r&b', 'canadian pop', 'pop']
# Starboy
# 94
#
# Until I Found You (with Em Beihold) - Em Beihold Version
# Stephen Sanchez 80 ['gen z singer-songwriter']
# Until I Found You (Em Beihold Version)
# 94
#
# Another Love
# Tom Odell 78 ['chill pop']
# Long Way Down
# 64
#
# I Ain't Worried
# OneRepublic 84 ['piano rock', 'pop']
# OneRepublic (Japan Paradise Tour Edition)
# 55
#
# Never Felt So Alone
# Labrinth 81 ['indie poptimism', 'pop']
# Never Felt So Alone
# 88
#
# La Bachata
# Manuel Turizo 85 ['colombian pop', 'reggaeton', 'reggaeton colombiano', 'trap latino', 'urbano latino']
# 2000
# 86
#
# Like Crazy
# Jimin 86 ['k-pop']
# FACE
# 93
#
# Hey Mor
# Ozuna 88 ['puerto rican pop', 'reggaeton', 'trap latino', 'urbano latino']
# OzuTochi
# 92
#
# Mockingbird
# Eminem 92 ['detroit hip hop', 'hip hop', 'rap']
# Encore (Deluxe Version)
# 93
#
# Por las Noches
# Peso Pluma 93 ['corrido', 'nueva musica mexicana', 'sad sierreno', 'sierreno']
# Por las Noches
# 91
#
# Rara Vez
# Taiu 75 []
# Rara Vez
# 93
#
# Quevedo: Bzrp Music Sessions, Vol. 52
# Bizarrap 87 ['argentine hip hop', 'pop venezolano', 'trap argentino', 'trap latino', 'urbano latino']
# Quevedo: Bzrp Music Sessions, Vol. 52
# 94
#
# Escapism.
# RAYE 80 ['uk contemporary r&b', 'uk pop']
# My 21st Century Blues
# 88
#
# Coco Chanel
# Eladio Carrion 87 ['trap boricua', 'trap latino', 'trap triste', 'urbano latino']
# 3MEN2 KBRN
# 93
#
# Players
# Coi Leray 79 ['new jersey underground rap', 'trap queen']
# Players
# 93
#
# OMG
# NewJeans 83 ['k-pop', 'k-pop girl group']
# NewJeans 'OMG'
# 94
#
# Kill Bill (feat. Doja Cat)
# SZA 92 ['pop', 'r&b', 'rap']
# Kill Bill (feat. Doja Cat)
# 85
#
# El Gordo Trae El Mando
# Chino Pacas 77 ['corrido']
# El Gordo Trae El Mando
# 92

# %%
sp.audio_features(track_uri)[0]
# Out:
# {'danceability': 0.736,
#  'energy': 0.8,
#  'key': 7,
#  'loudness': -5.38,
#  'mode': 0,
#  'speechiness': 0.0525,
#  'acousticness': 0.179,
#  'instrumentalness': 0,
#  'liveness': 0.0498,
#  'valence': 0.961,
#  'tempo': 140.253,
#  'type': 'audio_features',
#  'id': '3kf0WdFOalKWBkCCLJo4mA',
#  'uri': 'spotify:track:3kf0WdFOalKWBkCCLJo4mA',
#  'track_href': 'https://api.spotify.com/v1/tracks/3kf0WdFOalKWBkCCLJo4mA',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3kf0WdFOalKWBkCCLJo4mA',
#  'duration_ms': 112087,
#  'time_signature': 3}

# %%
print(track_uri)
# Out:
# spotify:track:3kf0WdFOalKWBkCCLJo4mA

# %% [markdown]
# Flow
